# %% [markdown]
# USGS background (didn't find anything):
# * https://coastalmap.marine.usgs.gov/regional/contusa/
# * https://www.usgs.gov/products/data-and-tools/apis
#
#
# Map to USGS Water Level Gauges https://maps.waterdata.usgs.gov/mapper/index.html
# Gauge Elevation statement: https://waterdata.usgs.gov/wa/nwis/current/?type=datum
#
# NOAA Tide Gauge: https://tidesandcurrents.noaa.gov/inventory.html?id=8735180 when using replace id with correct id.
# https://tidesandcurrents.noaa.gov/ports/ports.html?id=8735180&mode=threedayswl

# %%
# Use USGS API to collect gauge data and save as Pandas DataFrame.

import requests
import os
import pandas as pd
import datetime
import json
        
class noaa_gauge():
    def __init__(self, name, siteNumber, beginDate, endDate, main_dir, form):
        self.name = name #String name for the gauge
        self.siteNumber = siteNumber # Gauge site number  
        self.beginDate = beginDate
        self.endDate = endDate
        
        self.main_dir = main_dir
        self.form = form # Output format is 'json', 'rdb' [Tab delimited format]        
        
        # Base functions to copmlete operations of class.
        api_dates = self.ApiDateLimit()
        for date in api_dates:
            if not self.CheckForFile(date[0]):
                self.NoaaBuildGauge(date)

    def __repr__(self):
        return "<Gauge name: %s \n site_no:%s \n out format:%s" \
    % (self.name, self.siteNumber, self.form)
    
    def NoaaBuildGauge(self, date):
        self.url = 'https://tidesandcurrents.noaa.gov/api/datagetter?'
           
        self.gauge = {
            'product': 'water_level',
            'application': '=NOS.COOPS.TAC.WL',
            'begin_date': date[0],
            'end_date': date[1],
            'datum': 'NAVD',
            'station': self.siteNumber,
            'time_zone': 'lst',
            'units': 'english',
            'format': 'json',            
        }

        response = requests.get(self.url, params=self.gauge)
        self.status_code = response.status_code
        if response.status_code == 200:
            output = response.content.decode('utf-8')

        self.SaveGauge(output, date[0])
        
    def SaveGauge(self, output, yyyymmdd):
        save_file = self.MakeSaveFile(yyyymmdd)
        s = save_file.split('/')
        f = [key for key, value in json.loads(output).items()]
        
        if f[0] != 'error':
            with open(save_file, 'w') as infile:
                infile.write(output)                
                print(s[len(s)-1] + ' saved')
        else:
            print('error - no data: ' + s[len(s)-1])
            
    def MakeSaveFile(self, yyyymmdd):
        yyyymm = int(yyyymmdd/100) # remove day from date and save and YYYYMM.
        yyyymm = str(yyyymm)
        save_file = name.replace(" ", "_")+'_'+yyyymm # Define save file name        
        if form == 'json':
            save_file = save_file+'.json'
        elif form == 'rdb':
            save_file = save_file+'.txt'
        elif form == 'csv':
            save_file = save_file+'.csv'
        else:
            print('Need to classify form as json, rdb, or csv.')
        file_path = os.path.join(self.main_dir, save_file)
        return file_path
        
    
    def CheckForFile(self, yyyymmdd):        
        save_file = self.MakeSaveFile(yyyymmdd)
        print(save_file)
        if os.path.isfile(save_file):
            return True
        else:
            return False        
            
    
    def ApiDateLimit(self):
        '''
        Makes list of start and end dates to meet NOAAAPI 
        limits queries to 31 days so the date ranges must be limited.
        '''
        # Convert NOAA format to DateTime
        start = self.NoaaDateToDatetime(self.beginDate)
        end = self.NoaaDateToDatetime(self.endDate)
        
        # Create lists of low and high date tuples.
        noaa_date_start =[]
        noaa_date_end = []
        if end.year-start.year == 0:
            year = [start.year]
        else:
            year = range(start.year, end.year+1)
        month = range(1,12+1)
        year_month = [(y, m) for y in year for m in month]
        for ym in year_month:
            if ym[1] in [1,3,5,7,8,10,12]: #check if month should be 30 or 31 days, Feb assumed to have 30 days.
                days = 31
            elif ym[1] in [2]:
                if ym[0] % 4 == 0:
                    days=29
                else:
                    days=28
            elif ym[1] < 12:
                days=30
            else:
                print('Month is not 1...12.')

            nds = self.DatetimeToNoaaDate(ym[0], ym[1], 1)
            nde = nds + days - 1
            #2. collect and save each month until end date month and year reached.
            noaa_date_start.append(nds)
            noaa_date_end.append(nde)
        return zip(noaa_date_start, noaa_date_end)
    
    def NoaaDateToDatetime(self, date):
        year = int(date / 10000)
        month = int((date-year*10000)/100)
        day = date-year*10000-month*100
        return datetime.date(year=year, month=month, day=day)
    
    def DatetimeToNoaaDate(self, year, month, day):
        return (year)*10000 + month*100 + day
    
    

            ###TODO add gauge test I found for URL returns.
        
  
main_dir = '/home/moose/Documents/jupyter/alabama'
form = 'json'

name = 'Dauphin Island'
siteNumber = 8735180
beginDate = 20000101
endDate = 20191231

DI = noaa_gauge(name, siteNumber, beginDate, endDate, main_dir, form)
DI

# noaa_guage.ApiDateLimit(beginDate, endDate)
# Out:
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200001.json
# error - no data: Dauphin_Island_200001.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200002.json
# error - no data: Dauphin_Island_200002.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200003.json
# error - no data: Dauphin_Island_200003.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200004.json
# error - no data: Dauphin_Island_200004.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200005.json
# error - no data: Dauphin_Island_200005.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200006.json
# error - no data: Dauphin_Island_200006.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200007.json
# error - no data: Dauphin_Island_200007.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200008.json
# error - no data: Dauphin_Island_200008.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200009.json
# error - no data: Dauphin_Island_200009.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200010.json
# error - no data: Dauphin_Island_200010.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200011.json
# error - no data: Dauphin_Island_200011.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200012.json
# error - no data: Dauphin_Island_200012.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200101.json
# error - no data: Dauphin_Island_200101.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200102.json
# error - no data: Dauphin_Island_200102.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200103.json
# error - no data: Dauphin_Island_200103.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200104.json
# error - no data: Dauphin_Island_200104.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200105.json
# error - no data: Dauphin_Island_200105.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200106.json
# error - no data: Dauphin_Island_200106.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200107.json
# error - no data: Dauphin_Island_200107.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200108.json
# error - no data: Dauphin_Island_200108.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200109.json
# Dauphin_Island_200109.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200110.json
# Dauphin_Island_200110.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200111.json
# Dauphin_Island_200111.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200112.json
# Dauphin_Island_200112.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200201.json
# Dauphin_Island_200201.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200202.json
# Dauphin_Island_200202.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200203.json
# Dauphin_Island_200203.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200204.json
# Dauphin_Island_200204.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200205.json
# Dauphin_Island_200205.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200206.json
# Dauphin_Island_200206.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200207.json
# Dauphin_Island_200207.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200208.json
# Dauphin_Island_200208.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200209.json
# Dauphin_Island_200209.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200210.json
# Dauphin_Island_200210.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200211.json
# error - no data: Dauphin_Island_200211.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200212.json
# Dauphin_Island_200212.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200301.json
# Dauphin_Island_200301.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200302.json
# Dauphin_Island_200302.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200303.json
# Dauphin_Island_200303.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200304.json
# Dauphin_Island_200304.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200305.json
# Dauphin_Island_200305.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200306.json
# Dauphin_Island_200306.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200307.json
# Dauphin_Island_200307.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200308.json
# Dauphin_Island_200308.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200309.json
# error - no data: Dauphin_Island_200309.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200310.json
# error - no data: Dauphin_Island_200310.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200311.json
# Dauphin_Island_200311.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200312.json
# Dauphin_Island_200312.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200401.json
# Dauphin_Island_200401.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200402.json
# Dauphin_Island_200402.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200403.json
# Dauphin_Island_200403.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200404.json
# Dauphin_Island_200404.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200405.json
# Dauphin_Island_200405.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200406.json
# Dauphin_Island_200406.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200407.json
# Dauphin_Island_200407.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200408.json
# Dauphin_Island_200408.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200409.json
# Dauphin_Island_200409.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200410.json
# Dauphin_Island_200410.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200411.json
# Dauphin_Island_200411.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200412.json
# Dauphin_Island_200412.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200501.json
# Dauphin_Island_200501.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200502.json
# Dauphin_Island_200502.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200503.json
# Dauphin_Island_200503.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200504.json
# Dauphin_Island_200504.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200505.json
# Dauphin_Island_200505.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200506.json
# Dauphin_Island_200506.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200507.json
# Dauphin_Island_200507.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200508.json
# Dauphin_Island_200508.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200509.json
# Dauphin_Island_200509.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200510.json
# Dauphin_Island_200510.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200511.json
# Dauphin_Island_200511.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200512.json
# Dauphin_Island_200512.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200601.json
# error - no data: Dauphin_Island_200601.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200602.json
# Dauphin_Island_200602.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200603.json
# Dauphin_Island_200603.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200604.json
# Dauphin_Island_200604.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200605.json
# Dauphin_Island_200605.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200606.json
# Dauphin_Island_200606.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200607.json
# Dauphin_Island_200607.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200608.json
# Dauphin_Island_200608.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200609.json
# Dauphin_Island_200609.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200610.json
# Dauphin_Island_200610.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200611.json
# Dauphin_Island_200611.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200612.json
# Dauphin_Island_200612.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200701.json
# Dauphin_Island_200701.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200702.json
# Dauphin_Island_200702.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200703.json
# Dauphin_Island_200703.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200704.json
# Dauphin_Island_200704.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200705.json
# Dauphin_Island_200705.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200706.json
# Dauphin_Island_200706.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200707.json
# Dauphin_Island_200707.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200708.json
# Dauphin_Island_200708.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200709.json
# Dauphin_Island_200709.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200710.json
# Dauphin_Island_200710.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200711.json
# Dauphin_Island_200711.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200712.json
# Dauphin_Island_200712.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200801.json
# Dauphin_Island_200801.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200802.json
# Dauphin_Island_200802.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200803.json
# Dauphin_Island_200803.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200804.json
# Dauphin_Island_200804.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200805.json
# Dauphin_Island_200805.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200806.json
# Dauphin_Island_200806.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200807.json
# Dauphin_Island_200807.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200808.json
# Dauphin_Island_200808.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200809.json
# Dauphin_Island_200809.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200810.json
# Dauphin_Island_200810.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200811.json
# Dauphin_Island_200811.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200812.json
# Dauphin_Island_200812.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200901.json
# Dauphin_Island_200901.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200902.json
# Dauphin_Island_200902.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200903.json
# Dauphin_Island_200903.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200904.json
# Dauphin_Island_200904.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200905.json
# Dauphin_Island_200905.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200906.json
# Dauphin_Island_200906.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200907.json
# Dauphin_Island_200907.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200908.json
# Dauphin_Island_200908.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200909.json
# Dauphin_Island_200909.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200910.json
# Dauphin_Island_200910.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200911.json
# Dauphin_Island_200911.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_200912.json
# Dauphin_Island_200912.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201001.json
# Dauphin_Island_201001.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201002.json
# Dauphin_Island_201002.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201003.json
# Dauphin_Island_201003.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201004.json
# Dauphin_Island_201004.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201005.json
# Dauphin_Island_201005.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201006.json
# Dauphin_Island_201006.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201007.json
# Dauphin_Island_201007.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201008.json
# Dauphin_Island_201008.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201009.json
# Dauphin_Island_201009.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201010.json
# Dauphin_Island_201010.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201011.json
# Dauphin_Island_201011.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201012.json
# Dauphin_Island_201012.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201101.json
# Dauphin_Island_201101.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201102.json
# Dauphin_Island_201102.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201103.json
# Dauphin_Island_201103.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201104.json
# Dauphin_Island_201104.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201105.json
# Dauphin_Island_201105.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201106.json
# Dauphin_Island_201106.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201107.json
# Dauphin_Island_201107.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201108.json
# Dauphin_Island_201108.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201109.json
# Dauphin_Island_201109.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201110.json
# Dauphin_Island_201110.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201111.json
# Dauphin_Island_201111.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201112.json
# Dauphin_Island_201112.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201201.json
# Dauphin_Island_201201.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201202.json
# Dauphin_Island_201202.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201203.json
# Dauphin_Island_201203.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201204.json
# Dauphin_Island_201204.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201205.json
# Dauphin_Island_201205.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201206.json
# Dauphin_Island_201206.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201207.json
# Dauphin_Island_201207.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201208.json
# Dauphin_Island_201208.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201209.json
# Dauphin_Island_201209.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201210.json
# Dauphin_Island_201210.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201211.json
# Dauphin_Island_201211.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201212.json
# Dauphin_Island_201212.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201301.json
# Dauphin_Island_201301.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201302.json
# Dauphin_Island_201302.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201303.json
# Dauphin_Island_201303.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201304.json
# Dauphin_Island_201304.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201305.json
# Dauphin_Island_201305.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201306.json
# Dauphin_Island_201306.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201307.json
# Dauphin_Island_201307.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201308.json
# Dauphin_Island_201308.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201309.json
# Dauphin_Island_201309.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201310.json
# Dauphin_Island_201310.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201311.json
# Dauphin_Island_201311.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201312.json
# Dauphin_Island_201312.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201401.json
# Dauphin_Island_201401.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201402.json
# Dauphin_Island_201402.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201403.json
# Dauphin_Island_201403.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201404.json
# Dauphin_Island_201404.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201405.json
# Dauphin_Island_201405.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201406.json
# Dauphin_Island_201406.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201407.json
# Dauphin_Island_201407.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201408.json
# Dauphin_Island_201408.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201409.json
# Dauphin_Island_201409.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201410.json
# Dauphin_Island_201410.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201411.json
# Dauphin_Island_201411.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201412.json
# Dauphin_Island_201412.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201501.json
# Dauphin_Island_201501.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201502.json
# Dauphin_Island_201502.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201503.json
# Dauphin_Island_201503.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201504.json
# Dauphin_Island_201504.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201505.json
# Dauphin_Island_201505.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201506.json
# Dauphin_Island_201506.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201507.json
# Dauphin_Island_201507.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201508.json
# Dauphin_Island_201508.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201509.json
# Dauphin_Island_201509.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201510.json
# Dauphin_Island_201510.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201511.json
# Dauphin_Island_201511.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201512.json
# Dauphin_Island_201512.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201601.json
# Dauphin_Island_201601.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201602.json
# Dauphin_Island_201602.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201603.json
# Dauphin_Island_201603.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201604.json
# Dauphin_Island_201604.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201605.json
# Dauphin_Island_201605.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201606.json
# Dauphin_Island_201606.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201607.json
# Dauphin_Island_201607.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201608.json
# Dauphin_Island_201608.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201609.json
# Dauphin_Island_201609.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201610.json
# Dauphin_Island_201610.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201611.json
# Dauphin_Island_201611.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201612.json
# Dauphin_Island_201612.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201701.json
# Dauphin_Island_201701.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201702.json
# Dauphin_Island_201702.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201703.json
# Dauphin_Island_201703.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201704.json
# Dauphin_Island_201704.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201705.json
# Dauphin_Island_201705.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201706.json
# Dauphin_Island_201706.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201707.json
# Dauphin_Island_201707.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201708.json
# Dauphin_Island_201708.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201709.json
# Dauphin_Island_201709.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201710.json
# Dauphin_Island_201710.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201711.json
# Dauphin_Island_201711.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201712.json
# Dauphin_Island_201712.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201801.json
# Dauphin_Island_201801.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201802.json
# Dauphin_Island_201802.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201803.json
# Dauphin_Island_201803.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201804.json
# Dauphin_Island_201804.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201805.json
# Dauphin_Island_201805.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201806.json
# Dauphin_Island_201806.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201807.json
# Dauphin_Island_201807.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201808.json
# Dauphin_Island_201808.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201809.json
# Dauphin_Island_201809.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201810.json
# Dauphin_Island_201810.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201811.json
# Dauphin_Island_201811.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201812.json
# Dauphin_Island_201812.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201901.json
# Dauphin_Island_201901.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201902.json
# Dauphin_Island_201902.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201903.json
# Dauphin_Island_201903.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201904.json
# Dauphin_Island_201904.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201905.json
# Dauphin_Island_201905.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201906.json
# Dauphin_Island_201906.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201907.json
# Dauphin_Island_201907.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201908.json
# Dauphin_Island_201908.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201909.json
# Dauphin_Island_201909.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201910.json
# Dauphin_Island_201910.json saved
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201911.json
# error - no data: Dauphin_Island_201911.json
# /home/moose/Documents/jupyter/alabama/Dauphin_Island_201912.json
# error - no data: Dauphin_Island_201912.json
# <Gauge name: Dauphin Island
#  site_no:8735180
#  out format:json

# %%
import pandas as pd
import json

file_path = '/home/moose/Documents/jupyter/alabama/Dauphin_Island_201201.json'

with open(file_path, 'r') as infile:
    inf = json.load(infile)
    for key, value in inf.items():
        print(key)
#     print(pd.io.json.json_normalize(inf['metadata']))
#     print(pd.io.json.json_normalize(inf['data']))
    
    
        
# t: lst - local standard time
# v: observed water elevation (feet)
# s: predicted water elevation (feet)
# q: v is verified, p is preliminary
# Out:
# metadata
# data
